# %%
import pandas as pd
filename="weather.csv"

# %%
weather=pd.read_csv(filename)

# %%
weather.to_html(header=True,index=False, sparsify=False
            )
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th>city</th>\n      <th>lat</th>\n      <th>long</th>\n      <th>temp</th>\n      <th>clouds</th>\n      <th>humid</th>\n      <th>wind</th>\n      <th>humidity</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <td>jamestown</td>\n      <td>42.10</td>\n      <td>-79.24</td>\n      <td>77.32</td>\n      <td>1.0</td>\n      <td>50.0</td>\n      <td>13.87</td>\n      <td>50.0</td>\n    </tr>\n    <tr>\n      <td>paamiut</td>\n      <td>61.99</td>\n      <td>-49.67</td>\n      <td>46.15</td>\n      <td>99.0</td>\n      <td>79.0</td>\n      <td>2.10</td>\n      <td>79.0</td>\n    </tr>\n    <tr>\n      <td>la reforma</td>\n      <td>25.08</td>\n      <td>-108.05</td>\n      <td>91.00</td>\n      <td>10.0</td>\n      <td>64.0</td>\n      <td>8.01</td>\n      <td>64.0</td>\n    </tr>\n    <tr>\n      <td>bengkulu</td>\n      <td>-3.80</td>\n      <td>102.27</td>\n      <td>75.70</td>\n      <
# ...
